# %%
#importing necessery libraries for future analysis of the dataset
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import urllib.request as req
import seaborn as sns

# %% [markdown]
# Data explaination:
# - Time:
# - Seconds_elapsed: the number of seconds since you tapped the Start Recording button
# - x
# - y
# - x
# - z
# - altitude
# - speedAccuracy
# - bearingAccuracy
# - atitude
# - bearing
# - horizontalAccuracy
# - verticalAccuracy
# - longitude
# - speed
# - recording time
# - sensors
# - yaw
# - qx
# - qz
# - roll
# - qw
# - qy
# - pitch

# %%
#using pandas library and 'read_json' function to read json files
uBahn_1=pd.read_json("/Users/tramduong/Desktop/Python/ML4B/uBahn/uBahn_Bauernfeindstr._-_Langwasser_Mitte-2023-05-24_06-22-01 2.json")
uBahn_2=pd.read_json("/Users/tramduong/Desktop/Python/ML4B/uBahn/uBahn_Hbf-Friedrich_Ebert_Platz-2023-05-23_11-21-01 2.json")
#uBahn_2=pd.read_csv("/Users/tramduong/Downloads/ubahn_2.csv")
#auto_stadt=pd.read_csv("/Users/
bus_1=pd.read_json("/Users/tramduong/Downloads/Bus-2023-05-23_16-24-45.json")
fahhrad_1=pd.read_json("/Users/tramduong/Downloads/Fahrrad.json")

# %%
fahrrad_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62479 entries, 0 to 62478
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sensor              62479 non-null  object
#  1   time                62478 non-null  float64
#  2   seconds_elapsed     62478 non-null  float64
#  3   z                   54588 non-null  float64
#  4   y                   54588 non-null  float64
#  5   x                   54588 non-null  float64
#  6   bearingAccuracy     36 non-null     float64
#  7   speedAccuracy       36 non-null     float64
#  8   verticalAccuracy    36 non-null     float64
#  9   horizontalAccuracy  36 non-null     float64
#  10  speed               36 non-null     float64
#  11  bearing             36 non-null     float64
#  12  altitude            36 non-null     float64
#  13  longitude           36 non-null     float64
#  14  latitude            36 non-null     float64
# ...

# %%
bus_1.head()
# Out:
#           sensor          time  seconds_elapsed         z         y         x  \
# 0  Accelerometer  1.684859e+18         0.186288 -0.408691  0.242815 -0.344383
# 1  Accelerometer  1.684859e+18         0.191139 -0.379442  0.226482 -0.358854
# 2  Accelerometer  1.684859e+18         0.195992 -0.359389  0.221654 -0.340880
# 3  Accelerometer  1.684859e+18         0.200843 -0.325021  0.211375 -0.349141
# 4  Accelerometer  1.684859e+18         0.205694 -0.276657  0.183744 -0.316261
#
#    bearingAccuracy  speedAccuracy  verticalAccuracy  horizontalAccuracy  ...  \
# 0              NaN            NaN               NaN                 NaN  ...
# 1              NaN            NaN               NaN                 NaN  ...
# 2              NaN            NaN               NaN                 NaN  ...
# 3              NaN            NaN               NaN                 NaN  ...
# 4              NaN            NaN               NaN                 NaN  ...
#
# ...

# %%
uBahn_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230171 entries, 0 to 230170
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sensor                     230171 non-null  object
#  1   time                       230170 non-null  float64
#  2   seconds_elapsed            230170 non-null  float64
#  3   z                          200833 non-null  float64
#  4   y                          200833 non-null  float64
#  5   x                          200833 non-null  float64
#  6   relativeAltitude           269 non-null     float64
#  7   pressure                   269 non-null     float64
#  8   altitude                   282 non-null     float64
#  9   speedAccuracy              282 non-null     float64
#  10  bearingAccuracy            282 non-null     float64
#  11  latitude                   282 non-null     float64
#  12  altitudeAboveMeanSeaLevel  282 non-null     float64
# ...

# %%
bus_1.describe(include='all').transpose()
# Out:
#                       count unique  \
# sensor                62479     11
# time                62478.0    NaN
# seconds_elapsed     62478.0    NaN
# z                   54588.0    NaN
# y                   54588.0    NaN
# x                   54588.0    NaN
# bearingAccuracy        36.0    NaN
# speedAccuracy          36.0    NaN
# verticalAccuracy       36.0    NaN
# horizontalAccuracy     36.0    NaN
# speed                  36.0    NaN
# bearing                36.0    NaN
# altitude               36.0    NaN
# longitude              36.0    NaN
# latitude               36.0    NaN
# version                 1.0    NaN
# device name               1      1
# recording time            1      1
# platform                  1      1
# appVersion                1      1
# device id                 1      1
# sensors                   1      1
# sampleRateMs              1      1
# qz                   7854.0    NaN
# qy                   7854.0    NaN
# ...

# %%
#Bahn.drop(columns=['pressure])
uBahn_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230171 entries, 0 to 230170
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sensor                     230171 non-null  object
#  1   time                       230170 non-null  float64
#  2   seconds_elapsed            230170 non-null  float64
#  3   z                          200833 non-null  float64
#  4   y                          200833 non-null  float64
#  5   x                          200833 non-null  float64
#  6   relativeAltitude           269 non-null     float64
#  7   pressure                   269 non-null     float64
#  8   altitude                   282 non-null     float64
#  9   speedAccuracy              282 non-null     float64
#  10  bearingAccuracy            282 non-null     float64
#  11  latitude                   282 non-null     float64
#  12  altitudeAboveMeanSeaLevel  282 non-null     float64
# ...

# %%
#Drop collumns
uBahn_1.drop(['pressure','relativeAltitude','altitudeAboveMeanSeaLevel', ], axis=1)

# %%
#sns.lineplot(data=ICE)
#ICE.plot(x='longitude', y='altitude')
plt.scatter(x=ICE['longitude'], y=ICE['latitude'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #sns.lineplot(data=ICE)
#       2 #ICE.plot(x='longitude', y='altitude')
# ----> 3 plt.scatter(x=ICE['longitude'], y=ICE['latitude'])
#
# NameError: name 'ICE' is not defined
